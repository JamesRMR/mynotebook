# %%
import os
import hashlib

# %%
my_dir = rf"C:\Users\james.richmond\Desktop\test_files\my_dir"

# %%
def gen_files(path: str, num_files: int, extension: str = "debug"):
    for x in range(num_files):
        file_name = f"test_file_{_hash(x)}.{extension}"

        with open(rf"{path}\{file_name}", 'w') as f:
            pass

    print(f"Created {num_files} files")

# %%
gen_files(my_dir, 8)
# Out:
# Created 8 files

# %%
with open(rf"{my_dir}\x.txt", 'w') as f:
    pass

# %%
my_hsah = x

# %%
def _hash(data: int) -> str:
    return hashlib.sha256(str(data).encode('utf-8')).hexdigest()[:6]

# %%
my_hash = make_6_char_hex_hash(1)

# %%
my_hash
# Out:
# '6b86b2'

# %%
new_path = rf"D:\Clients\Orange Tree Co-RMROTREE\File Feeds"

with open(rf"{new_path}\new.debug", "w") as f:
    pass
