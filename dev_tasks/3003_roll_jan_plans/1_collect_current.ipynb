# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
import pandas as pd

current_dir = os.getcwd()
parent_dir = os.path.dirname(f"{"\\".join(current_dir.split("\\")[:-1])}")
sys.path.append(parent_dir)

from utils.collector import (
    get_all_elv_organizations,
    get_all_elv_plans,
    get_all_cu_clients,
    get_all_cu_plans,
)

cache_path = "./cache"
# Out:
# 200

# %%
all_orgs = pd.read_pickle("./cache/all_orgs.pkl")
print(len(all_orgs))
# all_orgs = get_all_elv_organizations()
# all_orgs.to_pickle(f"{cache_path}/all_orgs.pkl")
# Out:
# 1597

# %%
all_elv_plans = pd.read_pickle("./cache/all_elv_plans.pkl")
print(len(all_elv_plans))
# all_oids = all_orgs['organization_id'].to_list()
# all_elv_plans = get_all_elv_plans(oids=all_oids)
# all_elv_plans.to_pickle(f"{cache_path}/all_elv_plans.pkl")
# Out:
# 5868

# %%
all_clients = pd.read_pickle("./cache/all_clients.pkl")
print(len(all_clients))
# all_clients = get_all_cu_clients()
# all_clients.to_pickle(f"{cache_path}/all_clients.pkl")
# Out:
# 2765

# %%
all_cu_plans = pd.read_pickle("./cache/all_plans.pkl")
print(len(all_cu_plans))
# all_cu_plans = get_all_cu_plans()
# all_cu_plans.to_pickle(f"{cache_path}/all_cu_plans.pkl")
# Out:
# 6187
