# %%
from rockyelevate.wrapper import Session

# %%
elv = Session("PROD", multithread=True, max_threads=40)

# %%
plan_years = elv.get_plan_years(oids=[8717])

# %%
display(plan_years)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 display(plan_years)
#
# NameError: name 'plan_years' is not defined

# %%
display([p for p in plan_years if "2026" in p.get("valid_from")])
# Out:
# []
