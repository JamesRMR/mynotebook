# %%
plan_columns = [
    'plan_id',
    'plan_parent_id',
    'plan_year_id',
    'is_plan',
    'is_forfeited',
    'is_replenished_plan',
    'plan_code',
    'plan_omnibus_account_id',
    'notional_payroll_account_id',
    'notional_funding_account_id',
    'plan_status',
    'organization_id',
    'plan_organization_path',
    'deletable',
    'name.name',
    'name.name_state',
    'account_type.account_type',
    'account_type.account_type_state',
    'plan_primary_config.available_balance_type.available_balance_type',
    'plan_primary_config.available_balance_type.available_balance_type_state',
    'plan_primary_config.max_election_amount_type.max_election_amount',
    'plan_primary_config.max_election_amount_type.max_election_amount_type',
    'plan_primary_config.max_election_amount_type.irs_limit_type',
    'plan_primary_config.max_election_amount_type.max_election_amount_type_state',
    'plan_primary_config.min_election_amount_type.min_election_amount',
    'plan_primary_config.min_election_amount_type.min_election_amount_type',
    'plan_primary_config.min_election_amount_type.min_election_amount_type_state',
    'plan_primary_config.is_carded.is_carded',
    'plan_primary_config.is_carded.is_carded_state',
    'plan_primary_config.is_cip_required.is_cip_required',
    'plan_primary_config.is_cip_required.is_cip_required_state',
    'plan_primary_config.cip_account_closure_delay_days.cip_account_closure_delay_days',
    'plan_primary_config.cip_account_closure_delay_days.cip_account_closure_delay_days_state',
    'plan_primary_config.return_funds_after_cip_account_closure_type.return_funds_after_cip_account_closure_type',
    'plan_primary_config.return_funds_after_cip_account_closure_type.return_funds_after_cip_account_closure_type_state',
    'plan_primary_config.omnibus_type.omnibus_type',
    'plan_primary_config.omnibus_type.omnibus_type_state',
    'plan_primary_config.is_replenished.is_replenished',
    'plan_primary_config.is_replenished.is_replenished_state',
    'plan_primary_config.fund_id.fund_id',
    'plan_primary_config.fund_id.fund_state_id',
    'plan_primary_config.fund_id_formula.fund_id_formula',
    'plan_primary_config.fund_id_formula.fund_id_formula_state',
    'plan_primary_config.proof_of_expenses_type.proof_of_expenses_type',
    'plan_primary_config.proof_of_expenses_type.proof_of_expenses_type_state',
    'plan_primary_config.proof_of_expenses_card_type.proof_of_expenses_card_type',
    'plan_primary_config.proof_of_expenses_card_type.proof_of_expenses_type_state',
    'plan_primary_config.allow_investments.allow_investments',
    'plan_primary_config.allow_investments.allow_investments_state',
    'plan_primary_config.catch_up_election.catch_up_election',
    'plan_primary_config.catch_up_election.catch_up_election_state',
    'plan_primary_config.catch_up_age.catch_up_age',
    'plan_primary_config.catch_up_age.catch_up_age_state',
    'plan_primary_config.investment_options_type.investment_options_types',
    'plan_primary_config.investment_options_type.investment_options_type_state',
    'plan_primary_config.investment_threshold.investment_threshold',
    'plan_primary_config.investment_threshold.investment_threshold_state',
    'plan_primary_config.minimum_investment_amount.minimum_investment_amount',
    'plan_primary_config.minimum_investment_amount.minimum_investment_amount_state',
    'plan_primary_config.pend_contributions_for_cip.pend_contributions_for_cip',
    'plan_primary_config.pend_contributions_for_cip.pend_contributions_for_cip_state',
    'plan_primary_config.cms_reporting_required.cms_reporting_required',
    'plan_primary_config.cms_reporting_required.cms_reporting_required_state',
    'plan_primary_config.spend_limit_type.spend_limit',
    'plan_primary_config.spend_limit_type.spend_limit_type',
    'plan_primary_config.spend_limit_type.irs_limit_type',
    'plan_primary_config.spend_limit_type.spend_limit_type_state',
    'plan_primary_config.spend_period_type.spend_period_type',
    'plan_primary_config.spend_period_type.spend_period_type_state',
    'plan_primary_config.is_orphaned.is_orphaned',
    'plan_primary_config.is_orphaned.is_orphaned_state',
    'plan_primary_config.generate_statements.generate_statements',
    'plan_primary_config.generate_statements.generate_statements_state_id',
    'plan_primary_config.include_to_balance_reminder.include_to_balance_reminder',
    'plan_primary_config.include_to_balance_reminder.include_to_balance_reminder_state',
    'plan_primary_config.funding_method_type.funding_method_type',
    'plan_primary_config.funding_method_type.funding_method_type_state',
    'plan_primary_config.ignore_election_limit.ignore_election_limit',
    'plan_primary_config.ignore_election_limit.ignore_election_limit_state',
    'plan_coverage_config.grace_period_type.grace_period_days_amount',
    'plan_coverage_config.grace_period_type.grace_period_type',
    'plan_coverage_config.grace_period_type.grace_period_type_state',
    'plan_coverage_config.run_out_type.run_out_days_amount',
    'plan_coverage_config.run_out_type.run_out_type',
    'plan_coverage_config.run_out_type.run_out_type_state',
    'plan_coverage_config.end_of_coverage_type.end_of_coverage_days_amount',
    'plan_coverage_config.end_of_coverage_type.end_of_coverage_type',
    'plan_coverage_config.end_of_coverage_type.end_of_coverage_state',
    'plan_coverage_config.claims_deadline_end_of_coverage_type.claims_deadline_end_of_coverage_days_amount',
    'plan_coverage_config.claims_deadline_end_of_coverage_type.claims_deadline_end_of_coverage_type',
    'plan_coverage_config.claims_deadline_end_of_coverage_type.claims_deadline_end_of_coverage_state',
    'plan_coverage_config.is_pay_claims_absence.is_pay_claims_absence',
    'plan_coverage_config.is_pay_claims_absence.is_pay_claims_absence_state',
    'plan_coverage_config.is_pay_claims_outside_coverage.is_pay_claims_outside_coverage',
    'plan_coverage_config.is_pay_claims_outside_coverage.is_pay_claims_outside_coverage_state',
    'plan_coverage_config.ai_adjudication_type.ai_adjudication_type',
    'plan_coverage_config.ai_adjudication_type.ai_adjudication_type_state',
    'plan_account_funding_config.is_rollover.is_rollover',
    'plan_account_funding_config.is_rollover.is_rollover_state',
    'plan_account_funding_config.max_rollover_amount.max_rollover_amount_type',
    'plan_account_funding_config.max_rollover_amount.max_rollover_amount',
    'plan_account_funding_config.max_rollover_amount.max_rollover_irs_limit_type',
    'plan_account_funding_config.max_rollover_amount.max_rollover_amount_type_state',
    'plan_account_funding_config.min_rollover_amount.min_rollover_amount',
    'plan_account_funding_config.min_rollover_amount.min_rollover_amount_type',
    'plan_account_funding_config.min_rollover_amount.min_rollover_amount_type_state',
    'plan_account_funding_config.rollover_claims.rollover_claims_days_amount',
    'plan_account_funding_config.rollover_claims.rollover_claims_type',
    'plan_account_funding_config.rollover_claims.rollover_claims_type_state',
    'plan_account_funding_config.is_auto_enrollment.is_auto_enrollment',
    'plan_account_funding_config.is_auto_enrollment.is_auto_enrollment_state',
    'plan_account_funding_config.allow_contribution_config.employee.is_pre_tax',
    'plan_account_funding_config.allow_contribution_config.employee.pre_tax_memo',
    'plan_account_funding_config.allow_contribution_config.employee.is_post_tax',
    'plan_account_funding_config.allow_contribution_config.employee.post_tax_memo',
    'plan_account_funding_config.allow_contribution_config.employer.is_pre_tax',
    'plan_account_funding_config.allow_contribution_config.employer.pre_tax_memo',
    'plan_account_funding_config.allow_contribution_config.employer.is_post_tax',
    'plan_account_funding_config.allow_contribution_config.employer.post_tax_memo',
    'plan_account_funding_config.allow_contribution_config.type',
    'plan_account_funding_config.allow_contribution_config.state',
    'plan_account_funding_config.is_allow_contributions_over_election_amount.is_allow_contributions_over_election_amount',
    'plan_account_funding_config.is_allow_contributions_over_election_amount.is_allow_contributions_over_election_amount_state',
    'plan_account_funding_config.is_pend_contributions_over_irs.is_pend_contributions_over_the_irs_max',
    'plan_account_funding_config.is_pend_contributions_over_irs.is_pend_contributions_over_the_irs_max_state',
    'plan_account_funding_config.interest_template_id.interest_template_id',
    'plan_account_funding_config.interest_template_id.interest_template_id_state_id',
    'plan_account_funding_config.account_creation.account_creation_type',
    'plan_account_funding_config.account_creation.account_creation_type_state',
    'plan_account_funding_config.days_after_plan_end.days_after_plan_end',
    'plan_account_funding_config.days_after_plan_end.days_after_plan_end_state',
    'plan_account_funding_config.is_plan_level_funding.is_plan_level_funding',
    'plan_account_funding_config.is_plan_level_funding.is_plan_level_funding_state',
    'plan_account_funding_config.contribution_monitoring_required.contribution_monitoring_required',
    'plan_account_funding_config.contribution_monitoring_required.contribution_monitoring_required_state',
    'plan_account_funding_config.replenishment_bank_account_id',
    'plan_account_funding_config.replenishment_method',
    'plan_account_funding_config.replenishment_frequency',
    'plan_account_funding_config.replenishment_day_number',
    'plan_account_funding_config.contribution_bank_account_id',
    'plan_account_funding_config.contribution_method',
    'plan_account_funding_config.contribution_hold_period',
    'plan_account_funding_config.is_custom_prefund_calc.is_custom_prefund_calc',
    'plan_account_funding_config.is_custom_prefund_calc.is_custom_prefund_calc_state',
    'plan_account_funding_config.prefund_replenishment_percent.prefund_replenishment_percent',
    'plan_account_funding_config.prefund_replenishment_percent.prefund_replenishment_percent_state',
    'plan_account_funding_config.prefund_replenishment_min_value.prefund_replenishment_min_value',
    'plan_account_funding_config.prefund_replenishment_min_value.prefund_replenishment_min_value_state',
    'plan_account_funding_config.prefund_replenishment_creep_percent.prefund_replenishment_creep_percent',
    'plan_account_funding_config.prefund_replenishment_creep_percent.prefund_replenishment_creep_percent_state',
    'plan_account_funding_config.prefund_replenishment_creep_min.prefund_replenishment_creep_min',
    'plan_account_funding_config.prefund_replenishment_creep_min.prefund_replenishment_creep_min_state',
    'plan_account_funding_config.allow_individual_contributions.allow_individual_contributions',
    'plan_account_funding_config.allow_individual_contributions.allow_individual_contributions_state_id',
    'plan_account_funding_config.minimum_contribution_amount.minimum_contribution_amount',
    'plan_account_funding_config.minimum_contribution_amount.minimum_contribution_amount_state_id',
    'plan_account_funding_config.is_forfeit_allowed.is_forfeit_allowed',
    'plan_account_funding_config.is_forfeit_allowed.is_forfeit_allowed_state',
    'plan_account_funding_config.forfeiture_days.forfeiture_days',
    'plan_account_funding_config.forfeiture_days.forfeiture_days_state',
    'plan_account_funding_config.is_account_maintenance_fees_enabled.is_account_maintenance_fees_enabled',
    'plan_account_funding_config.is_account_maintenance_fees_enabled.is_account_maintenance_fees_enabled_state',
    'plan_account_funding_config.account_maintenance_fees_amount',
    'plan_account_funding_config.apply_account_maintenance_fees_to',
    'plan_account_funding_config.account_maintenance_fees_threshold',
    'plan_year.id',
    'plan_year.organization_id',
    'plan_year.name',
    'plan_year.valid_from',
    'plan_year.valid_to',
    'plan_year.organization_path',
    'plan_year.prior_plan_year_id',
    'plan_year.prior_plan_year.id',
    'plan_year.prior_plan_year.name',
    'plan_year.prior_plan_year.valid_from',
    'plan_year.prior_plan_year.valid_to',
    'service_configs.DENTAL',
    'service_configs.VISION',
    'service_configs.MEDICAL',
    'service_configs.PHARMACY',
    'cu_account_type',
    'external_identifier',
    'name',
    'organization_status_type',
    'organization_status_valid_from',
    'created_at',
    'activation_started',
    'is_locked',
    'is_limited_features_during_termination_in_progress',
    'organization_parent_id',
    'type',
    'organization_organization_path',
    'termination_date',
    'short_name',
    'business_entity_type',
    'client_id',
    'prior_plan_card',
    'prior_plan_card_id'
]

print(len(plan_columns))
# Out:
# 198
