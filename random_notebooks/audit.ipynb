# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests

from rockyclickup.wrapper import Session

# %%
clickup = Session()

# %%
clickup.base
# Out:
# 'https://api.clickup.com/api/v2'

# %%
workspace_id = 9011096643
audit = clickup.post(f"https://api.clickup.com/api/v3/workspaces/9011096643/auditlogs")

# %%
audit
# Out:
# ('https://api.clickup.com/api/v3/workspaces/9011096643/auditlogs',
#  {'err': 'not_found_or_authorized',
#   'status': 404,
#   'message': 'Not Found or Authorized',
#   'timestamp': '2025-10-17T22:55:23.356Z',
#   'ECODE': 'ACCESS_999',
#   'meta': {'authorization_failures': [{'object_id': '9011096643',
#      'object_type': 'workspace',
#      'workspace_id': 9011096643,
#      'code': 'INSUFFICIENT_ACCESS',
#      'invalid_permissions': ['can_view_audit_logs']}]}})

# %%
audit = requests.get()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\james.richmond\Desktop\repos\mynotebook\venv\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...
