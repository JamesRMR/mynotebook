# %%
import json

from client import FireStore

# %%
auth_json_path = rf"G:\Shared drives\Development\.env\rmr-cloud-services-auth.json"

# %%
with open(auth_json_path, "r") as f:
    auth_json = json.load(f)

# %%
firestore = FireStore(
    collection_name="cloud_data",
    authentication=auth_json
)

# %%
en_file_map = firestore.get_document("EN_file_map")

# %%
values = en_file_map.values()

# %%
print(len(list(values)))
print(len(set(values)))
# Out:
# 170
# 170
