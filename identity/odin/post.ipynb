# %%
import requests

AUTH_URL = rf"https://auth-841365555979.us-west3.run.app/"
BASE_URL = rf"https://identity-sandbox-841365555979.us-west3.run.app"

# %%
headers = {"Authorization": f"Bearer {token}"}

# create new entity
response = requests.post(
    url=f"{BASE_URL}/identity/mappings",
    json={"system_code": "rmr", "external_id": "RMROTREE", "kind": "company"},
    headers=headers,
)

response.json()

# res -> entity_id = f2f90208-9898-46c4-843a-23e7da3c7841

# %%
clickup_res = requests.post(
    url=f"{BASE_URL}/identity/mappings",
    json={
        "system_code": "clickup",
        "external_id": "868k3tyep",
        "kind": "company",
        "entity_id": "f2f90208-9898-46c4-843a-23e7da3c7841"
    },
    headers=headers,

)

# %%
clickup_res.json()

# %%
correct_res = requests.patch(
    url=f"{BASE_URL}/identity/mappings/1/868k3tyep",
    json={"entity_id"}
)

# %%
delete_res = requests.delete(
    url=f"{BASE_URL}/identity/entities/eab97c70-9b61-4d8e-9767-96cbcb427ba3",
    headers=headers,
)

# %%
delete_res
