# %%
from rockyfilescom.wrapper import Session

# %%
rfc = Session()

# %%
my_file = rfc.get_file("Clients/Trident Systems-RMRTRD/File Feeds/Trident-RMRTRD_Term_20260825.csv")

# %%
my_file.custom_metadata
# Out:
# {'gateway_task_id': '868kwhefd'}
