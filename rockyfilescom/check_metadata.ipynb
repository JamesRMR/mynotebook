# %%
from rockyfilescom.wrapper import Session

# %%
rfc = Session()

# %%
filepath = rf"\Clients\Orange Tree Co-RMROTREE\File Feeds\TOP_TEN_SECRET_TEST_SUBSTRINGS.txt"

# %%
rfc_file = rfc.get_file(filepath)

# %%
rfc_file.custom_metadata

# %%
task_id = "868kwack0"

# %%
rfc_file.custom_metadata = "custom_2"

# %%
rfc_file.custom_metadata

# %%
rfc_file.update({"custom_metadata": {"wtf": "the hell"}})

# %%
rfc_file.custom_metadata

# %%
from rmrhermes.chatterbox import Chatterbox
