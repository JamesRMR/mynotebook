# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rockyclickup import wrapper, models,  utils

cu = wrapper.Session()

opps = cu.get_full_list(models.Opportunity.list_id)

# %%
df = utils.response_to_dataframe(opps)

# %%
df['services']

# %%
sorted(list(df.columns))

# %%
from rockyclickup.database_interface import get_options_by_field, get_custom_field

# %%
my_field = get_custom_field(field_id="dc4192aa-db71-4970-8ddc-d252d95eea2c")

# %%
my_field.custom_name

# %%
field_id = "dc4192aa-db71-4970-8ddc-d252d95eea2c"

# %%
options = get_options_by_field(field_id=field_id)

# %%
options_dict = {o.name: o.option_id for o in options}
options_dict
