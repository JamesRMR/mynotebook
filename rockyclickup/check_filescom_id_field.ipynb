# %%
from rockyclickup.wrapper import Session
from rockyclickup.utils import response_to_dataframe
from rockyclickup.models import DataFile

# %%
rcu = Session()

# %%
rcu.headers

# %%
my_task = rcu.get_task_by_id("868kyjxt8")

# %%
my_task

# %%
all_datafiles = rcu.get_full_list(list_id=DataFile.list_id)

# %%
datafile_df = response_to_dataframe(all_datafiles)

# %%
files_com_ids = datafile_df[datafile_df['filescom_id'].notna()]
files_com_ids

# %%
[c for c in datafile_df.columns if "id" in c]
