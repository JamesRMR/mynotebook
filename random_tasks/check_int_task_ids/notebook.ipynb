# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
clients = pd.read_pickle(r"C:\Users\james.richmond\Desktop\repos\mynotebook\cache\250929_ALL_CLIENTS_CLICKUP.pkl")

# %%
int_task_ids = clients[clients['client_id'].apply(lambda x: x.isnumeric())]

# %%
int_task_ids
# Out:
#       client_id                     client_name cu_client_description  \
# 872   868781798                Tegelerinsurance
# 873   868781797           TechnoAlpin USA, Inc.
# 874   868781795           TechInsights USA, Inc
# 875   868781793             Taylor Anderson LLP
# 876   868781791                            TARC
# ...         ...                             ...                   ...
# 1027  868781707                    Leeds Equity
# 1028  868781703           Latitude 36 Foods LLC
# 1029  868781702  Laird Norton Wealth Management
# 1030  868781700          La Jolla Music Society
# 1260  868781613      Visiting Nurse Association
#
#       cu_client_archived cu_client_assignees cu_client_assignees  \
# 872                False                  []                  []
# 873                False                  []                  []
# 874                False                  []                  []
# 875                False                  []                  []
# ...

# %%
display(clients[clients['client_name'].apply(lambda x: "client_id" in x.lower())])
# Out:
# Empty DataFrame
# ...
