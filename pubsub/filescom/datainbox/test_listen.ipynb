# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os

root_dir = os.path.dirname(os.getcwd())
if root_dir not in sys.path:
    sys.path.append(root_dir)

from datainbox import PubSubClient, run_consumer

# %%
PROJECT_ID = 'rmr-cloud-services'
SUBSCRIPTION_ID = 'filescom-events-sub'

# %%
client = PubSubClient(project_id=PROJECT_ID)

# %%
result = run_consumer(
    subscription=SUBSCRIPTION_ID,
    max_messages=10,
    handlers=None,
    alerter=None,
    services=None,
    client=client,
)
