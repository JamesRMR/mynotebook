# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
import sysconfig

current_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(current_dir))
sys.path.append(root_dir)

# %%
from datainbox.services import default_services
services = default_services()

# %%
res = services.clickup.search_datafiles(
    ftp_directory="/Clients/Catholic Diocese of Lafayette-RMRCDL/File Feeds",
    ftp_filename="Catholic Diocese of Lafayette RMRCDL_DemoElect_20260731.csv"
)

# %%
my_datafile = services.clickup.get_task("asdfa")

# %%
my_datafile

# %%
res

# %%
from rockyfilescom.wrapper import Session as RFC

# %%
rfc = RFC()

# %%
my_file = rfc.get_file(rf"Clients\Orange Tree Co-RMROTREE\File Feeds\webhook.txt")

# %%
my_file.custom_metadata

# %%
from datainbox.services import IdentityService

# %%
id_service = IdentityService()

# %%
print(os.getenv("IDENTITY_DB_CONNECTION_NAME"))
# Out:
# rmr-cloud-services:us-west3:gateway-services

# %%
from datainbox.services import ClickUpService
clickup = ClickUpService()

# %%
clickup.link_datafile_to_datacard(datacard_id="868kmd9ud", datafile_id="868kmd8jd")

# %%
# return response_to_model(self.session.get_task_by_id(task_id))

# %%
my_client = clickup.get_client("868k3tyep")
# Out:
# Field not in config.db:	59c3f678-807b-4984-9deb-bd87b5818c9b	`EDI Project Mgmt`

# %%
my_client
# Out:
# Client(markdown=False, name='Orange Tree Co.', id='868k3tyep', text_content='', description='', markdown_description=None, status='onboarding', order_index='121039604.81344078000000000000000000000000', date_created=datetime.datetime(2026, 6, 22, 13, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800), 'Mountain Daylight Time')), date_updated=datetime.datetime(2026, 7, 30, 15, 37, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800), 'Mountain Daylight Time')), date_closed=None, date_done=None, archived=False, tags=[{'name': 'debug', 'tag_fg': '#8077F1', 'tag_bg': '#595d66', 'creator': 50835299}, {'name': 'demo', 'tag_fg': '#8c1d28', 'tag_bg': '#ff5e00', 'creator': 50835299}], priority=None, due_date=None, start_date=None, points=None, time_estimate=None, time_spent=0, team_id='9011096643', url='https://app.clickup.com/t/868k3tyep', permission_level='create', space_id='90110612617', list_id=901102596133, rmr_code='RMROTREE', eligible_employee_count=N
# ...
