# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
import sysconfig

current_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(current_dir))
sys.path.append(root_dir)

# %%
from datainbox.services import IdentityService

# %%
from datainbox.services import ClickUpService
clickup = ClickUpService()

# %%
# clickup.link_datafile_to_datacard(datacard_id="868k3tyep", datafile_id="868kmd8jd")

# %%
rmrcode = "RMROTREE"

# %%
id_service = IdentityService()

identity_db = id_service.db
# Out:
# connecting to db. connection params:
# {'instance_connection_name': 'rmr-cloud-services:us-west3:gateway-services', 'db_name': 'identity_sandbox', 'user': 'james', 'password': 'SzoLj7&rtezkN#dL'}
# Connected to 'identity_sandbox' via rmr-cloud-services:us-west3:gateway-services

# %%
client_id = id_service.client_id_from_rmrcode(rmrcode)
if client_id is None:
    print(f"not linking {'N/A'}: no clickup task id for {rmrcode} in identity database")
# Out:
# searching for rmrcode RMROTREE
# not linking N/A: no clickup task id for RMROTREE in identity database
