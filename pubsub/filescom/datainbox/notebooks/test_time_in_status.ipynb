# %%
import sys, os

current_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(current_dir))
sys.path.append(root_dir)

from datainbox.services import default_services

# %%
services = default_services()

# %%
my_task = services.clickup.get_task("868kmuj41")

# %%
my_task
# Out:
# DataFile(markdown=False, name='webhook.txt', id='868kmuj41', text_content='', description='', markdown_description=None, status='new', order_index='10001785960163.22790700000000000000000000000000', date_created=datetime.datetime(2026, 8, 5, 14, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800), 'Mountain Daylight Time')), date_updated=datetime.datetime(2026, 8, 5, 14, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800), 'Mountain Daylight Time')), date_closed=None, date_done=None, archived=False, tags=[], priority=None, due_date=None, start_date=None, points=None, time_estimate=None, time_spent=0, team_id='9011096643', url='https://app.clickup.com/t/868kmuj41', permission_level='create', space_id='90110612618', list_id=901102710355, inbox=['868kmd9ud'], notes=None, am=None, preserve_division=None, ftp_user='james.richmond@rmrbenefits.com', ftp_directory='Clients/Orange Tree Co-RMROTREE/File Feeds', filescom_id=None, review_status=None, last_reviewed=None, ftp_filename='webhook.txt', received=datetime.datetime(2026, 8, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800), 'Mountain Daylight Time')), file_category='Client Inbox', file_date=datetime.datetime(2026, 8, 5, 20, 2, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=64800), 'Mountain Daylight Time')), last_emailed=None)

# %%
my_task.notes
# Out:
# 'notes'

# %%
for k, v in my_task.__dict__.items():
    print(f"{k:<25} {v}")
# Out:
# markdown                  False
# name                      webhook.txt
# id                        868kmuj41
# text_content
# description
# markdown_description      None
# status                    new
# order_index               10001785960163.22790700000000000000000000000000
# date_created              2026-08-05 14:02:00-06:00
# date_updated              2026-08-05 14:02:00-06:00
# date_closed               None
# date_done                 None
# archived                  False
# tags                      []
# priority                  None
# due_date                  None
# start_date                None
# points                    None
# time_estimate             None
# time_spent                0
# team_id                   9011096643
# url                       https://app.clickup.com/t/868kmuj41
# permission_level          create
# space_id                  90110612618
# list_id                   901102710355
# inbox                     ['868kmd9ud']
# notes                     None
# am                        None
# preserve_division         None
# ftp_user                  james.richmond@rmrbenefits.com
# ftp_directory             Clients/Orange Tree Co-RMROTREE/File Feeds
# filescom_id               None
# review_status             None
# last_reviewed             None
# ftp_filename              webhook.txt
# received                  2026-08-05 00:00:00-06:00
# file_category             Client Inbox
# file_date                 2026-08-05 20:02:00-06:00
# last_emailed              None
