# %%
from rockyfilescom.wrapper import Session as RFC

# %%
rfc = RFC()

# %%
children = rfc.list_contents(rf"\Clients\Orange Tree Co-RMROTREE\File Feeds")

# %%
children

# %%
for child in children:
    print(getattr(child, "type", ))
